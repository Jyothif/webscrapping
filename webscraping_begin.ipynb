# %% [markdown]
# - Is webscrapping is illegal?
#
#        - Some websites allow and some other dont allow to scraping the website.
#
# - Why python is good for web scrapping
#     -   Ease of use
#     -   Large collection of libraries
#     -   easily understandable syntax
#     -   small code, large task
#     -   community
#
# **How do you scrape the website?**
#
#     1. Find the URL that allows and want to scrape
#     2. Inspecting the Page
#     3. Find the data you want to extract
#     4. write the code
#     5. Run the code and extract
#     6. store the data in the required format
#
# - Libraries used for Web scraping?
#        1. Selenium
#        2. BeautifulSoup
#        3. Pandas

# %% [markdown]
# # Web scrapping : FlipKart
#
# - pre requisites:
#
#     1. python 2.x or python3.x with selenium,BeautifulSoup, pandas libraries installed
#     2. google-chrome browser
#     3. Ubuntu OS

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-1.2.4-cp39-cp39-win_amd64.whl (9.3 MB)
# ...
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

# %%
url="https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=7ec220e8-4f02-4150-9e0b-9e90cf692f4b&as-searchtext=laptop"
response = requests.get(url)
htmlcontent = requests.get(url)
soup = BeautifulSoup(htmlcontent.text,"html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
products=[]
prices=[]
ratings=[]
product = soup.find('div',attrs={'class':'_4rR01T'})
print(product.text)
# Out:
# Mi Notebook 14 Core i5 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) JYU4298IN Thin and Light Laptop

# %%
# writing code for scraping
for a in soup.findAll('a',href=True,attrs={'class':'_1fQZEK'}):
    name = a.find('div',attrs={'class':'_4rR01T'})
    price = a.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
    rating = a.find('div',attrs={'class':'_3LWZlK'})
    products.append(name.text)
    prices.append(price.text)
    ratings.append(rating.text)

# %%
import pandas as pd
df = pd.DataFrame({"Product Name":products,
                  "Price":prices,
                   'Rating':ratings
                  })

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ad4c8cb1ccf5> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame({"Product Name":products,
#       3                   "Price":prices,
#       4                    'Rating':ratings
#       5                   })
#
# ~\.conda\envs\webscraping\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\.conda\envs\webscraping\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
# ...
